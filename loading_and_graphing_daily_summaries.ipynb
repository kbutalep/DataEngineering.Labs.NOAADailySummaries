# %%
import json_helper
import pandas as pd
import os
import json

# %%
# use json_helper to load all json objects into a dataframe called df_daily_summaries
file_path = os.path.join('./', 'data', 'daily_summaries')

def read_json(file_path):
    with open(file_path, 'r') as f:
        json_obj = json.load(f)
        return json_obj
    


# def read_all_json_files(JSON_ROOT):
#     df = pd.DataFrame()
#     ser = pd.Series()
#     for file_name in os.listdir(JSON_ROOT):
#         if file_name.find('daily_summaries') == -1:
#             continue
#         file_path = 'data/daily_summaries/' + file_name
#         data = read_json(file_path)
#         for obj in data['results']:
#             obj['source'] = file_name
#         df_daily_summaries = df.append(data['results'])
#     return df_daily_summaries

# %%
df1 = read_json('data/daily_summaries/daily_summaries_FIPS10003_jan_2018_0.json')
df1 = df1['results']

# %%
df2 = read_json('data/daily_summaries/daily_summaries_FIPS10003_jan_2018_1.json')
df2 = df2['results']

# %%
# display a summary of df_daily_summaries
df_daily_summaries=pd.DataFrame(df1)
df_daily_summaries=df_daily_summaries.append(df2)

df_daily_summaries
# Out:
# /var/folders/rw/1rnjc7b90vd_mr3753j04_s40000gp/T/ipykernel_44735/1972529811.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_daily_summaries=df_daily_summaries.append(df2)
#                     date datatype            station attributes  value
# 0    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0001   ,,N,0700      0
# 1    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0001  T,,N,0700      0
# 2    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0002   ,,N,0700      0
# 3    2018-01-01T00:00:00     SNOW  GHCND:US1DENC0002   ,,N,0700      0
# 4    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0002  T,,N,0700      0
# ..                   ...      ...                ...        ...    ...
# 381  2018-01-31T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 382  2018-01-31T00:00:00     WDF2  GHCND:USW00013781       ,,W,    320
# 383  2018-01-31T00:00:00     WDF5  GHCND:USW00013781       ,,W,    310
# 384  2018-01-31T00:00:00     WSF2  GHCND:USW00013781       ,,W,     89
# 385  2018-01-31T00:00:00     WSF5  GHCND:USW00013781       ,,W,    116
#
# [1386 rows x 5 columns]

# %% [markdown]
# How many stations are there in total for FIPS10003

# %%
# 1386

# %% [markdown]
# Create a DataFrame called temps_max that only contains the entries from df_daily_summaries where the datatype column is equal to TMAX. This DataFrame should only retain the date column and the value column.

# %%
temps_max = df_daily_summaries[df_daily_summaries['datatype'] == 'TMAX']

# %%
temps_max
# Out:
#                     date datatype            station attributes  value
# 42   2018-01-01T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -60
# 89   2018-01-02T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -38
# 138  2018-01-03T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     -5
# 193  2018-01-04T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -21
# 240  2018-01-05T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -82
# 279  2018-01-06T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -88
# 322  2018-01-07T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -71
# 365  2018-01-08T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      6
# 399  2018-01-09T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     78
# 443  2018-01-10T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     56
# 488  2018-01-11T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    133
# 529  2018-01-12T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    167
# 577  2018-01-13T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    139
# 621  2018-01-14T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    -32
# 670  2018-01-15T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      0
# 720  2018-01-16T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     56
# 773  2018-01-17T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     22
# 819  2018-01-18T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     22
# 864  2018-01-19T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     83
# 908  2018-01-20T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    139
# 955  2018-01-21T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    117
# 993  2018-01-22T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    156
# 33   2018-01-23T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    172
# 76   2018-01-24T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     72
# 119  2018-01-25T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     28
# 163  2018-01-26T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     39
# 206  2018-01-27T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    150
# 242  2018-01-28T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400    133
# 291  2018-01-29T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     78
# 334  2018-01-30T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400     39
# 380  2018-01-31T00:00:00     TMAX  GHCND:USW00013781   ,,W,2400      6

# %% [markdown]
# How many entries are there in the temps_max DataFrame? What are the mean, min, and max values?

# %%
temps_max.describe()
# Out:
#             value
# count   31.000000
# mean    48.193548
# std     77.768640
# min    -88.000000
# 25%     -2.500000
# 50%     39.000000
# 75%    125.000000
# max    172.000000

# %% [markdown]
# Let's graph this DataFrame so we can get a visual representation for this information.

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %% [markdown]
# Create a DataFrame called temps_min that only contains the entries from df_daily_summaries where the datatype column is equal to TMIN. This DataFrame should only retain the date column and the value column.

# %%
temps_min = df_daily_summaries[df_daily_summaries['datatype'] == 'TMIN']

# %%
temps_min
# Out:
#                     date datatype            station attributes  value
# 43   2018-01-01T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -149
# 90   2018-01-02T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -116
# 139  2018-01-03T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -132
# 194  2018-01-04T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 241  2018-01-05T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -121
# 280  2018-01-06T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -138
# 323  2018-01-07T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -166
# 366  2018-01-08T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -105
# 400  2018-01-09T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -60
# 444  2018-01-10T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -49
# 489  2018-01-11T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     33
# 530  2018-01-12T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     83
# 578  2018-01-13T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -71
# 622  2018-01-14T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400   -105
# 671  2018-01-15T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -88
# 721  2018-01-16T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -16
# 774  2018-01-17T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -77
# 820  2018-01-18T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -99
# 865  2018-01-19T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -66
# 909  2018-01-20T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -38
# 956  2018-01-21T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -32
# 994  2018-01-22T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     39
# 34   2018-01-23T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     44
# 77   2018-01-24T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400      6
# 120  2018-01-25T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -38
# 164  2018-01-26T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -66
# 207  2018-01-27T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -49
# 243  2018-01-28T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     72
# 292  2018-01-29T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400     33
# 335  2018-01-30T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -55
# 381  2018-01-31T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93

# %% [markdown]
# How many entries are there in the temps_min DataFrame? What are the mean, min, and max values?

# %%
temps_min.describe()
# Out:
#             value
# count   31.000000
# mean   -55.225806
# std     65.749378
# min   -166.000000
# 25%   -102.000000
# 50%    -66.000000
# 75%    -24.000000
# max     83.000000

# %% [markdown]
# Graph the temps_min DataFrame

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min Temperatues Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Min Temperatues Jan 2018')]

# %% [markdown]
# We can also plot both of these lines in the same graph.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Jan 2018')
# Out:
# [Text(0.5, 0, 'day of month'),
#  Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Jan 2018')]
